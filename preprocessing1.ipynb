# %%
# !pip install ultralytics -q

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd drive/MyDrive/analysis

# %%
import os
import pandas as pd
import numpy as np
import cv2
from ultralytics import YOLO
from glob import glob
# Out:
# WARNING  Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at 'C:\Users\kitano\AppData\Roaming\Ultralytics\settings.yaml'

# %%
true_df = pd.read_csv('data/true_data.csv')
pred_df = pd.read_csv('data/pred_data.csv')

# %%
pred_df.head()
# Out:
#                    path  phase     TOE_x     TOE_y   HOSEL_x   HOSEL_y  \
# 0  sony_white_0006_0543  train  0.172967  0.321406  0.206783  0.301450
# 1         red_0008_0364  train  0.852629  0.388099  0.845331  0.425212
# 2   sasaki_green_1_0070  train  0.557030  0.341899  0.548423  0.335616
# 3       white_0008_0000  train  0.386160  0.879610  0.411111  0.902188
# 4    sony_red_0015_0436  train  0.972876  0.480149  0.945886  0.499058
#
#      GRIP_x    GRIP_y
# 0  0.442091  0.344775
# 1  0.734720  0.556486
# 2  0.534622  0.412796
# 3  0.527084  0.623340
# 4  0.666625  0.480049
